# %%
# Import the required libraries and dependencies

import os

import requests

import json

import pandas as pd

from dotenv import load_dotenv

import alpaca_trade_api as tradeapi

#from MCForecastTools import MCSimulation

import datetime

# %matplotlib inline


# Load the environment variables from the .env file
#by calling the load_dotenv function

load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-49d97022049d> in <module>
#      23 #by calling the load_dotenv function
#      24
# ---> 25 load_dotenv()
#
# ~\anaconda3\envs\dev\lib\site-packages\dotenv\main.py in load_dotenv(dotenv_path, stream, verbose, override, interpolate, **kwargs)
#     317     """
#     318     f = dotenv_path or stream or find_dotenv()
# --> 319     return DotEnv(f, verbose=verbose, interpolate=interpolate, **kwargs).set_as_environment_variables(override=override)
#     320
#     321
#
# ~\anaconda3\envs\dev\lib\site-packages\dotenv\main.py in set_as_environment_variables(self, override)
#     104         Load the current dotenv as system environemt variable.
#     105         """
# --> 106         for k, v in self.dict().items():
#     107             if k in os.environ and not override:
#     108                 continue
#
# ~\anaconda3\envs\dev\lib\site-packages\dotenv\main.py in dict(self)
#      85
#      86         if self.interpolate:
# ---> 87             values = resolve_nested_variables(self.parse())
#      88         else:
#      89             values = OrderedDict(self.parse())
#
# ~\anaconda3\envs\dev\lib\site-packages\dotenv\main.py in resolve_nested_variables(values)
#     237     new_values = {}
#     238
# --> 239     for (k, v) in values:
#     240         new_values[k] = __posix_variable.sub(_re_sub_callback, v) if v is not None else None
#     241
#
# ~\anaconda3\envs\dev\lib\site-packages\dotenv\main.py in parse(self)
#      95         # type: () -> Iterator[Tuple[Text, Optional[Text]]]
#      96         with self._get_stream() as stream:
# ---> 97             for mapping in with_warn_for_invalid_lines(parse_stream(stream)):
#      98                 if mapping.key is not None:
#      99                     yield mapping.key, mapping.value
#
# ~\anaconda3\envs\dev\lib\site-packages\dotenv\main.py in with_warn_for_invalid_lines(mappings)
#      46 def with_warn_for_invalid_lines(mappings):
#      47     # type: (Iterator[Binding]) -> Iterator[Binding]
# ---> 48     for mapping in mappings:
#      49         if mapping.error:
#      50             logger.warning(
#
# ~\anaconda3\envs\dev\lib\site-packages\dotenv\parser.py in parse_stream(stream)
#     227 def parse_stream(stream):
#     228     # type: (IO[Text]) -> Iterator[Binding]
# --> 229     reader = Reader(stream)
#     230     while reader.has_next():
#     231         yield parse_binding(reader)
#
# ~\anaconda3\envs\dev\lib\site-packages\dotenv\parser.py in __init__(self, stream)
#     105     def __init__(self, stream):
#     106         # type: (IO[Text]) -> None
# --> 107         self.string = stream.read()
#     108         self.position = Position.start()
#     109         self.mark = Position.start()
#
# ~\anaconda3\envs\dev\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ---> 23         return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#      24
#      25 class StreamWriter(Codec,codecs.StreamWriter):
#
# UnicodeDecodeError: 'charmap' codec can't decode byte 0x9d in position 314: character maps to <undefined>

# %%
# The Free Crypto API Call endpoint URLs for the held cryptocurrency assets

btc_url = "https://api.alternative.me/v2/ticker/Bitcoin/?convert=USD"

eth_url = "https://api.alternative.me/v2/ticker/Ethereum/?convert=USD"

link_url = "https://api.alternative.me/v2/ticker/Chainlink/?convert=USD"

zec_url = "https://api.alternative.me/v2/ticker/Zcash/?convert=USD"

atom_url = "https://api.alternative.me/v2/ticker/Cosmos/?convert=USD"

algo_url = "https://api.alternative.me/v2/ticker/Algorand/?convert=USD"

# %%
# Using the Python requests library, make an API call to access the current price of BTC

btc_response = requests.get(btc_url).json()

# Use the json.dumps function to review the response data from the API call
# Use the indent and sort_keys parameters to make the response object readable
# YOUR CODE HERE

print(json.dumps(btc_response, indent=8, sort_keys=True))
# Out:
# {
#         "data": {
#                 "1": {
#                         "circulating_supply": 18631443,
#                         "id": 1,
#                         "last_updated": 1613598425,
#                         "max_supply": 21000000,
#                         "name": "Bitcoin",
#                         "quotes": {
#                                 "USD": {
#                                         "market_cap": 977643840416,
#                                         "percent_change_1h": 0.198059022443048,
#                                         "percent_change_24h": 8.03335491114384,
#                                         "percent_change_7d": 12.6146038361819,
#                                         "percentage_change_1h": 0.198059022443048,
#                                         "percentage_change_24h": 8.03335491114384,
#                                         "percentage_change_7d": 12.6146038361819,
#                                         "price": 52444.0,
#                                         "volume_24h": 68815574641
#                                 }
#                         },
#                         "rank": 1,
#                         "symbol": "BTC",
#                         "total_supply": 18631443,
#                         "website_slug": "bitcoin"
#                 }
#         },
#         "metadata": {
#                 "error": null,
#                 "num_cryptocurrencies": 1362,
#                 "timestamp": 1613598425
#         }
# }

# %%
# Using the Python requests library, make an API call to access the current price ETH

eth_response = requests.get(eth_url).json()

# YOUR CODE HERE

# Use the json.dumps function to review the response data from the API call
# Use the indent and sort_keys parameters to make the response object readable
# YOUR CODE HERE
print(json.dumps(eth_response, indent=8, sort_keys=True))
# Out:
# {
#         "data": {
#                 "1027": {
#                         "circulating_supply": 114713162,
#                         "id": 1027,
#                         "last_updated": 1613598406,
#                         "max_supply": 0,
#                         "name": "Ethereum",
#                         "quotes": {
#                                 "USD": {
#                                         "market_cap": 211195882581,
#                                         "percent_change_1h": 0.441633192982421,
#                                         "percent_change_24h": 5.25140638843908,
#                                         "percent_change_7d": 4.16561040805772,
#                                         "percentage_change_1h": 0.441633192982421,
#                                         "percentage_change_24h": 5.25140638843908,
#                                         "percentage_change_7d": 4.16561040805772,
#                                         "price": 1842.75,
#                                         "volume_24h": 33050449695
#                                 }
#                         },
#                         "rank": 2,
#                         "symbol": "ETH",
#                         "total_supply": 114713162,
#                         "website_slug": "ethereum"
#                 }
#         },
#         "metadata": {
#                 "error": null,
#                 "num_cryptocurrencies": 1362,
#                 "timestamp": 1613598406
#         }
# }

# %%
link_responce = requests.get(link_url).json()


print(json.dumps(link_responce, indent=8, sort_keys=True))
# Out:
# {
#         "data": {
#                 "1975": {
#                         "circulating_supply": 407009556,
#                         "id": 1975,
#                         "last_updated": 1613598460,
#                         "max_supply": 1000000000,
#                         "name": "Chainlink",
#                         "quotes": {
#                                 "USD": {
#                                         "market_cap": 13145637125,
#                                         "percent_change_1h": 0.559386887654558,
#                                         "percent_change_24h": 3.15780936501778,
#                                         "percent_change_7d": 17.2893863069315,
#                                         "percentage_change_1h": 0.559386887654558,
#                                         "percentage_change_24h": 3.15780936501778,
#                                         "percentage_change_7d": 17.2893863069315,
#                                         "price": 32.45,
#                                         "volume_24h": 2152013804
#                                 }
#                         },
#                         "rank": 10,
#                         "symbol": "LINK",
#                         "total_supply": 407009556,
#                         "website_slug": "chainlink"
#                 }
#         },
#         "metadata": {
#                 "error": null,
#                 "num_cryptocurrencies": 1362,
#                 "timestamp": 1613598460
#         }
# }

# %%
zec_responce = requests.get(zec_url).json()


print(json.dumps(zec_responce, indent=8, sort_keys=True))
# Out:
# {
#         "data": {
#                 "1437": {
#                         "circulating_supply": 10803588,
#                         "id": 1437,
#                         "last_updated": 1613598402,
#                         "max_supply": 21000000,
#                         "name": "Zcash",
#                         "quotes": {
#                                 "USD": {
#                                         "market_cap": 1815372204,
#                                         "percent_change_1h": -0.848819906139217,
#                                         "percent_change_24h": 10.7974777456202,
#                                         "percent_change_7d": 54.5911004550451,
#                                         "percentage_change_1h": -0.848819906139217,
#                                         "percentage_change_24h": 10.7974777456202,
#                                         "percentage_change_7d": 54.5911004550451,
#                                         "price": 168.05,
#                                         "volume_24h": 2004267835
#                                 }
#                         },
#                         "rank": 48,
#                         "symbol": "ZEC",
#                         "total_supply": 10803588,
#                         "website_slug": "zcash"
#                 }
#         },
#         "metadata": {
#                 "error": null,
#                 "num_cryptocurrencies": 1362,
#                 "timestamp": 1613598402
#         }
# }

# %%
atom_res = requests.get(atom_url).json()


print(json.dumps(atom_res, indent=8, sort_keys=True))
# Out:
# {
#         "data": {
#                 "1420": {
#                         "circulating_supply": 238526147,
#                         "id": 1420,
#                         "last_updated": 1613598515,
#                         "max_supply": 0,
#                         "name": "Cosmos",
#                         "quotes": {
#                                 "USD": {
#                                         "market_cap": 5812384225,
#                                         "percent_change_1h": -2.22998584184429,
#                                         "percent_change_24h": 0.312250824466913,
#                                         "percent_change_7d": 61.0208257558033,
#                                         "percentage_change_1h": -2.22998584184429,
#                                         "percentage_change_24h": 0.312250824466913,
#                                         "percentage_change_7d": 61.0208257558033,
#                                         "price": 24.28,
#                                         "volume_24h": 2085565698
#                                 }
#                         },
#                         "rank": 16,
#                         "symbol": "ATOM",
#                         "total_supply": 238526147,
#                         "website_slug": "cosmos"
#                 }
#         },
#         "metadata": {
#                 "error": null,
#                 "num_cryptocurrencies": 1362,
#                 "timestamp": 1613598515
#         }
# }

# %%
algo_responce = requests.get(algo_url).json()


print(json.dumps(algo_responce, indent=8, sort_keys=True))
# Out:
# {
#         "data": {
#                 "0": {
#                         "circulating_supply": 803088849,
#                         "id": 0,
#                         "last_updated": 1613598461,
#                         "max_supply": 10000000000,
#                         "name": "Algorand",
#                         "quotes": {
#                                 "USD": {
#                                         "market_cap": 1108655486,
#                                         "percent_change_1h": -2.51246593133247,
#                                         "percent_change_24h": 6.34032112866839,
#                                         "percent_change_7d": 33.724043219895,
#                                         "percentage_change_1h": -2.51246593133247,
#                                         "percentage_change_24h": 6.34032112866839,
#                                         "percentage_change_7d": 33.724043219895,
#                                         "price": 1.38,
#                                         "volume_24h": 936711268
#                                 }
#                         },
#                         "rank": 65,
#                         "symbol": "ALGO",
#                         "total_supply": 803088849,
#                         "website_slug": "algorand"
#                 }
#         },
#         "metadata": {
#                 "error": null,
#                 "num_cryptocurrencies": 1362,
#                 "timestamp": 1613598461
#         }
# }

# %%
btc_price = btc_response['data']['1']["quotes"]["USD"]["price"]

btc_price
# Out:
# 52444.0

# %%
btc_percentage_change_7d = btc_response['data']['1']["quotes"]["USD"]["percent_change_7d"]
btc_percentage_change_7d
# Out:
# 12.6146038361819

# %%
eth_price = eth_response['data']['1027']["quotes"]["USD"]["price"]

eth_price
# Out:
# 1842.75

# %%
eth_percentage_change_7d = eth_response['data']['1027']["quotes"]["USD"]["percent_change_7d"]
eth_percentage_change_7d
# Out:
# 4.16561040805772

# %%
link_price = link_responce['data']['1975']["quotes"]["USD"]["price"]

link_price
# Out:
# 32.45

# %%
link_percentage_change_7d = link_responce['data']['1975']["quotes"]["USD"]["percent_change_7d"]

link_percentage_change_7d
# Out:
# 17.2893863069315

# %%
zcash_percentage_change_7d =  zec_responce['data']['1437']["quotes"]["USD"]["percent_change_7d"]

# %%
zcash_percentage_change_7d
# Out:
# 54.5911004550451

# %%
atom_prices = atom_res['data']['1420']["quotes"]["USD"]["price"]
atom_prices
# Out:
# 24.28

# %%
atom_change = atom_res['data']['1420']["quotes"]["USD"]["percent_change_7d"]
atom_change
# Out:
# 61.0208257558033

# %%
algo_prices = algo_responce['data']['0']["quotes"]["USD"]["price"]
algo_prices
# Out:
# 1.38

# %%
algo_pct = algo_responce['data']['0']["quotes"]["USD"]["percent_change_7d"]
algo_pct
# Out:
# 33.724043219895
